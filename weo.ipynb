# %% [markdown]
# <a href="https://colab.research.google.com/github/epogrebnyak/weo-reader/blob/master/weo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Prepare installation

# %%
# !python -V
# Out:
# Python 3.6.9

# %%
# !pip uninstall -y  weo
# !pip install -U git+https://github.com/epogrebnyak/weo-reader.git

# %% [markdown]
# Get the data

# %%
import weo

# %%
weo.download(2020,2,"weo.csv")
# Out:
# weo.csv 18.3Mb
# Downloaded 2020-Oct WEO dataset
# ('weo.csv',
#  'https://www.imf.org/-/media/Files/Publications/WEO/WEO-Database/2020/02/WEOOct2020all.xls')

# %%
w = weo.WEO("weo.csv")

# %% [markdown]
# Key content

# %%
w.subjects
# Out:
# ['Gross domestic product, constant prices',
#  'Gross domestic product, current prices',
#  'Gross domestic product, deflator',
#  'Gross domestic product per capita, constant prices',
#  'Gross domestic product per capita, current prices',
#  'Output gap in percent of potential GDP',
#  'Gross domestic product based on purchasing-power-parity (PPP) share of world total',
#  'Implied PPP conversion rate',
#  'Total investment',
#  'Gross national savings',
#  'Inflation, average consumer prices',
#  'Inflation, end of period consumer prices',
#  'Six-month London interbank offered rate (LIBOR)',
#  'Volume of imports of goods and services',
#  'Volume of Imports of goods',
#  'Volume of exports of goods and services',
#  'Volume of exports of goods',
#  'Unemployment rate',
#  'Employment',
#  'Population',
#  'General government revenue',
#  'General government total expenditure',
#  'General government net lending/borrowing',
#  'General government structural balance',
#  'General government primary net lending/borrowing',
#  'General government net debt',
#  'General government gross debt',
#  'Gross domestic product corresponding to fiscal year, current prices',
#  'Current account balance']

# %%
w.codes
# Out:
# ['NGDP_R',
#  'NGDP_RPCH',
#  'NGDP',
#  'NGDPD',
#  'PPPGDP',
#  'NGDP_D',
#  'NGDPRPC',
#  'NGDPRPPPPC',
#  'NGDPPC',
#  'NGDPDPC',
#  'PPPPC',
#  'NGAP_NPGDP',
#  'PPPSH',
#  'PPPEX',
#  'NID_NGDP',
#  'NGSD_NGDP',
#  'PCPI',
#  'PCPIPCH',
#  'PCPIE',
#  'PCPIEPCH',
#  'FLIBOR6',
#  'TM_RPCH',
#  'TMG_RPCH',
#  'TX_RPCH',
#  'TXG_RPCH',
#  'LUR',
#  'LE',
#  'LP',
#  'GGR',
#  'GGR_NGDP',
#  'GGX',
#  'GGX_NGDP',
#  'GGXCNL',
#  'GGXCNL_NGDP',
#  'GGSB',
#  'GGSB_NPGDP',
#  'GGXONLB',
#  'GGXONLB_NGDP',
#  'GGXWDN',
#  'GGXWDN_NGDP',
#  'GGXWDG',
#  'GGXWDG_NGDP',
#  'NGDP_FY',
#  'BCA',
#  'BCA_NGDPD']

# %%
w.core_codes
# Out:
# ['NGDP',
#  'NGDP_RPCH',
#  'NGSD_NGDP',
#  'NID_NGDP',
#  'PCPIEPCH',
#  'PCPIPCH',
#  'NGDP_D',
#  'LP',
#  'LUR',
#  'GGR',
#  'GGX',
#  'GGXWDG',
#  'GGXWDN',
#  'GGXONLB',
#  'GGXCNL',
#  'NGDPD',
#  'BCA',
#  'PPPEX']

# %%
w.from_code("NGDP")
# Out:
# ('Gross domestic product, current prices', 'National currency')

# %%
w.from_code("LUR")
# Out:
# ('Unemployment rate', 'Percent of total labor force')

# %%
print(w.years)
# Out:
# ['1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023', '2024', '2025']

# %%
w.variables()
# Out:
# [('Gross domestic product, constant prices', 'National currency', 'NGDP_R'),
#  ('Gross domestic product, constant prices', 'Percent change', 'NGDP_RPCH'),
#  ('Gross domestic product, current prices', 'National currency', 'NGDP'),
#  ('Gross domestic product, current prices', 'U.S. dollars', 'NGDPD'),
#  ('Gross domestic product, current prices',
#   'Purchasing power parity; international dollars',
#   'PPPGDP'),
#  ('Gross domestic product, deflator', 'Index', 'NGDP_D'),
#  ('Gross domestic product per capita, constant prices',
#   'National currency',
#   'NGDPRPC'),
#  ('Gross domestic product per capita, constant prices',
#   'Purchasing power parity; 2017 international dollar',
#   'NGDPRPPPPC'),
#  ('Gross domestic product per capita, current prices',
#   'National currency',
#   'NGDPPC'),
#  ('Gross domestic product per capita, current prices',
#   'U.S. dollars',
#   'NGDPDPC'),
#  ('Gross domestic product per capita, current prices',
#   'Purchasing power parity; international dollars',
#   'PPPPC'),
#  ('Output gap in percent of potential GDP',
#   'Percent of potential GDP',
#   'NGAP_NPGDP'),
#  ('Gross domestic product based on purchasing-power-parity (PPP) share of world total',
#   'Percent',
#   'PPPSH'),
#  ('Implied PPP conversion rate',
#   'National currency per current international dollar',
#   'PPPEX'),
#  ('Total investment', 'Percent of GDP', 'NID_NGDP'),
#  ('Gross national savings', 'Percent of GDP', 'NGSD_NGDP'),
#  ('Inflation, average consumer prices', 'Index', 'PCPI'),
#  ('Inflation, average consumer prices', 'Percent change', 'PCPIPCH'),
#  ('Inflation, end of period consumer prices', 'Index', 'PCPIE'),
#  ('Inflation, end of period consumer prices', 'Percent change', 'PCPIEPCH'),
#  ('Six-month London interbank offered rate (LIBOR)', 'Percent', 'FLIBOR6'),
#  ('Volume of imports of goods and services', 'Percent change', 'TM_RPCH'),
#  ('Volume of Imports of goods', 'Percent change', 'TMG_RPCH'),
#  ('Volume of exports of goods and services', 'Percent change', 'TX_RPCH'),
#  ('Volume of exports of goods', 'Percent change', 'TXG_RPCH'),
#  ('Unemployment rate', 'Percent of total labor force', 'LUR'),
#  ('Employment', 'Persons', 'LE'),
#  ('Population', 'Persons', 'LP'),
#  ('General government revenue', 'National currency', 'GGR'),
#  ('General government revenue', 'Percent of GDP', 'GGR_NGDP'),
#  ('General government total expenditure', 'National currency', 'GGX'),
#  ('General government total expenditure', 'Percent of GDP', 'GGX_NGDP'),
#  ('General government net lending/borrowing', 'National currency', 'GGXCNL'),
#  ('General government net lending/borrowing', 'Percent of GDP', 'GGXCNL_NGDP'),
#  ('General government structural balance', 'National currency', 'GGSB'),
#  ('General government structural balance',
#   'Percent of potential GDP',
#   'GGSB_NPGDP'),
#  ('General government primary net lending/borrowing',
#   'National currency',
#   'GGXONLB'),
#  ('General government primary net lending/borrowing',
#   'Percent of GDP',
#   'GGXONLB_NGDP'),
#  ('General government net debt', 'National currency', 'GGXWDN'),
#  ('General government net debt', 'Percent of GDP', 'GGXWDN_NGDP'),
#  ('General government gross debt', 'National currency', 'GGXWDG'),
#  ('General government gross debt', 'Percent of GDP', 'GGXWDG_NGDP'),
#  ('Gross domestic product corresponding to fiscal year, current prices',
#   'National currency',
#   'NGDP_FY'),
#  ('Current account balance', 'U.S. dollars', 'BCA'),
#  ('Current account balance', 'Percent of GDP', 'BCA_NGDPD')]

# %%
w.units()
# Out:
# ['National currency',
#  'Percent change',
#  'U.S. dollars',
#  'Purchasing power parity; international dollars',
#  'Index',
#  'Purchasing power parity; 2017 international dollar',
#  'Percent of potential GDP',
#  'Percent',
#  'National currency per current international dollar',
#  'Percent of GDP',
#  'Percent of total labor force',
#  'Persons']

# %%
w.countries()
# Out:
#      WEO Country Code  ISO              Country
# 0                 512  AFG          Afghanistan
# 45                914  ALB              Albania
# 90                612  DZA              Algeria
# 135               614  AGO               Angola
# 180               311  ATG  Antigua and Barbuda
# ...               ...  ...                  ...
# 8550              582  VNM              Vietnam
# 8595              487  WBG   West Bank and Gaza
# 8640              474  YEM                Yemen
# 8685              754  ZMB               Zambia
# 8730              698  ZWE             Zimbabwe
#
# [195 rows x 3 columns]

# %% [markdown]
# Get data

# %%
w.country("JPN").head().T
# Out:
#                  1980        1981        1982        1983        1984
#
# NGDP       250636.200  268830.700  282582.000  295303.900  313145.300
# NGDP_RPCH       3.181       4.209       3.312       3.523       4.502
# NGSD_NGDP      30.299      30.810      29.707      28.856      29.725
# NID_NGDP       33.912      32.762      31.552      30.150      29.959
# PCPIEPCH        7.240       4.068       2.448       1.670       2.344
# PCPIPCH         7.808       4.916       2.744       1.900       2.262
# NGDP_D         96.167      98.982     100.709     101.661     103.159
# LP            116.769     117.623     118.451     119.271     120.050
# LUR             2.017       2.208       2.350       2.658       2.708
# GGR         67409.900   75950.500   80575.400   84192.200   91346.200
# GGX         78715.200   86529.500   91579.200   96105.600   99735.500
# GGXWDG     122341.900  145038.300  166617.300  191704.600  209705.200
# GGXWDN      44619.100   57895.000   73262.900   90702.100  103728.200
# GGXONLB     -8315.400   -7025.500   -6562.500   -6176.300   -1860.400
# GGXCNL     -11305.300  -10579.000  -11003.800  -11913.400   -8389.300
# NGDPD        1105.386    1218.989    1134.518    1243.324    1318.382
# BCA           -10.750       4.761       6.847      20.804      35.009
# PPPEX         239.870     225.551     216.133     209.954     205.628

# %%
w.getc("NGDP").tail().round(0).T
# Out:
#           2021       2022        2023        2024        2025
#
# AFG     1598.0     1742.0      1893.0      2048.0      2215.0
# ALB     1692.0     1827.0      1952.0      2077.0      2211.0
# DZA    20049.0    21574.0     22995.0     24565.0     26367.0
# AGO    45349.0    53459.0     60322.0     66626.0     72280.0
# ATG        4.0        4.0         5.0         5.0         6.0
# ..         ...        ...         ...         ...         ...
# VNM  8793233.0  9782467.0  10895377.0  12149433.0  13487743.0
# WBG       55.0       59.0        62.0        64.0        67.0
# YEM    18110.0    20762.0     24187.0     27915.0     32362.0
# ZMB      391.0      436.0       480.0       524.0       564.0
# ZWE      886.0      948.0       999.0      1070.0      1146.0
#
# [195 rows x 5 columns]

# %%
w.fix_year(2019).T
# Out:
# WEO Subject Code     BCA  BCA_NGDPD  FLIBOR6  ...  TM_RPCH  TXG_RPCH  TX_RPCH
# ISO                                           ...
# ABW                0.060      2.093      NaN  ...      NaN       NaN      NaN
# AFG                2.209     11.705      NaN  ...   -7.862     0.068   -5.116
# AGO                5.132      5.739      NaN  ...  -11.289     0.496    0.227
# ALB               -1.166     -7.632      NaN  ...    4.721    -8.454    1.699
# ARE               35.372      8.399      NaN  ...   -2.452    -0.976   -0.136
# ..                   ...        ...      ...  ...      ...       ...      ...
# WSM                0.019      2.282      NaN  ...      NaN       NaN      NaN
# YEM               -0.888     -3.933      NaN  ...   29.194    30.832   30.289
# ZAF              -10.599     -3.017      NaN  ...   -0.486    -2.351   -2.511
# ZMB                0.146      0.606      NaN  ...  -25.856   -12.488  -12.488
# ZWE                0.208      1.112      NaN  ...      NaN     5.966      NaN
#
# [195 rows x 45 columns]

# %% [markdown]
# Libor vs inflation - see negative real rates

# %%
import pandas as pd
libor = w.libor_usd()
infl = w.inflation()["USA"]
pd.DataFrame(dict(LIBOR=libor, CPI=infl)).plot(title = "USD 3M LIBOR and US CPI", cmap="Set2")

# %% [markdown]
# Everything for one country

# %%
import matplotlib.pyplot as plt
import pandas as pd
fig, axes = plt.subplots(
    nrows=3, ncols=3, figsize=(12 * 3 / 2, 8 * 3 / 2), facecolor="white"
)

iso_code = "GRC"
c = w.country(iso_code)

df = pd.DataFrame()
gdp = c.NGDP_RPCH.dropna()
gdp.iloc[0] = 1
# FIXME: must use .combine to fix start of GDP time series for Russia, Ukraine, etc

df["GDP"] = (c.NGDP_RPCH.dropna() / 100 + 1).cumprod() * 100
df["CPI"] = c.PCPIPCH
df["FX"] = c.NGDP / c.NGDPD
df["DEFICIT"] = (c.GGR - c.GGX) / c.NGDP * 100
df["CA"] = c.BCA / c.NGDPD * 100

df["_GDEBT"] = (c.GGXWDG / c.NGDP) * 100
df["_NDEBT"] = (c.GGXWDN / c.NGDP) * 100

min_cpi = round(min(0, c.PCPIPCH.min()) * 1.5, 0)
max_cpi = round(c.PCPIPCH.abs()[-1] * 5 / 2, 0) * 2

df.GDP.plot(ax=axes[0, 0], title=f"GDP growth, {gdp.index[0].year}=100")
c.LUR.plot(ax=axes[1, 0], title="Unemployment, %")
c.PCPIPCH.plot(
    ax=axes[0, 1], ylim =[min_cpi, max_cpi], title="Inflation, annual average, %"
).axhline( y=0, ls="-", lw=1, color="darkgrey")

  # FIXME: can draw deflator too here
df.FX.plot(
    ax=axes[1, 1], title="Exchange rate, national currency / USD, annual average"
)  # this is 1 for the US
(c.BCA / c.NGDPD * 100).plot(ax=axes[0, 2], title="Current account, % GDP").axhline(
    y=0, ls="-", lw=1, color="darkgrey"
)
df.DEFICIT.plot(ax=axes[1, 2], title="Budget deficit, % GDP").axhline(
    y=0, ls="-", lw=1, color="darkgrey"
)
df._GDEBT.plot(ax=axes[2, 2], title="Gross government debt, % GDP").axhline(
    y=0, ls="-", lw=1, color="darkgrey"
)
c.LP.plot(ax=axes[2, 0], title="Population, mln")
c.NGSD_NGDP.plot(ax=axes[2, 1], title="Savings and investment, % GDP")
c.NID_NGDP.plot(ax=axes[2, 1], color="lightblue")

plt.subplots_adjust(left=0.02, right=0.98, top=0.9, bottom=0.02)

fig.suptitle(w.country_name(iso_code) + f" ({iso_code})", x=0.02, ha="left")

for row in axes:
    for ax in row:
        ax.axvline(x="2020", ls="-", lw=0.5, color="lightblue")
#axes[0,1].axhline(y="0", ls="-", lw=0.5, color="orange")


plt.savefig(iso_code + ".png")
